# %%
import pandas as pd
import matplotlib.pyplot as plt
    
traditional_recommenders = [
    "ItemKNNCFRecommender",
    "SLIMElasticNetRecommender",
    "IALSRecommender"
]

for traditional_rec in traditional_recommenders:
    # Load the csv file into a pandas DataFrame
    df = pd.read_csv('/Users/lucaortolomo/Desktop/TESI/Thesis_DiffusionRecommender-main/experiment_data/DiffusionAutoencoderRecommender_'+ traditional_rec+'_TwoLevelRec.csv')

    #Precision, NDCG) e diversity (Item coverage, Item coverage hit e average precision)
    #PRECISION,PRECISION_RECALL_MIN_DEN,RECALL,MAP,MAP_MIN_DEN,MRR,NDCG,F1,HIT_RATE,
    # ARHR_ALL_HITS,NOVELTY,AVERAGE_POPULARITY,DIVERSITY_MEAN_INTER_LIST,DIVERSITY_HERFINDAHL,
    # COVERAGE_ITEM,COVERAGE_ITEM_HIT,ITEMS_IN_GT,COVERAGE_USER,COVERAGE_USER_HIT,USERS_IN_GT,
    # DIVERSITY_GINI,SHANNON_ENTROPY,RATIO_DIVERSITY_HERFINDAHL,RATIO_DIVERSITY_GINI,
    # RATIO_SHANNON_ENTROPY,RATIO_AVERAGE_POPULARITY,RATIO_NOVELTY,RECOMMENDER,PARAMS,TIMESTEPS


    # Set your timestamp column as index if it isn't
    df.set_index('TIMESTEPS', inplace=True)

    # List of column names  to plot
    columns_to_plot = ['NDCG', 'AVERAGE_POPULARITY', 'COVERAGE_ITEM',]  

    df[columns_to_plot].plot()

    plt.xlabel('Timesteps')
    plt.ylabel('Value')
    title = 'Timesteps study DIFF +' + traditional_rec
    plt.title(title)

    #  legend
    plt.legend(columns_to_plot)

    # Save the figure in PDF 
    plt.savefig(title +".pdf")

# %%
import pandas as pd
import matplotlib.pyplot as plt



traditional_recommenders = [
    "ItemKNNCFRecommender",
    "SLIMElasticNetRecommender",
    "IALSRecommender"
]

for traditional_rec in traditional_recommenders:

    # Load the csv file into a pandas DataFrame
    df = pd.read_csv('/Users/lucaortolomo/Desktop/TESI/Thesis_DiffusionRecommender-main/experiment_data/'+traditional_rec+'_DiffusionAutoencoderRecommender_TwoLevelRec.csv')



    #PRECISION,PRECISION_RECALL_MIN_DEN,RECALL,MAP,MAP_MIN_DEN,MRR,NDCG,F1,HIT_RATE,
    # ARHR_ALL_HITS,NOVELTY,AVERAGE_POPULARITY,DIVERSITY_MEAN_INTER_LIST,DIVERSITY_HERFINDAHL,
    # COVERAGE_ITEM,COVERAGE_ITEM_HIT,ITEMS_IN_GT,COVERAGE_USER,COVERAGE_USER_HIT,USERS_IN_GT,
    # DIVERSITY_GINI,SHANNON_ENTROPY,RATIO_DIVERSITY_HERFINDAHL,RATIO_DIVERSITY_GINI,
    # RATIO_SHANNON_ENTROPY,RATIO_AVERAGE_POPULARITY,RATIO_NOVELTY,RECOMMENDER,PARAMS,TIMESTEPS


    # Set your timestamp column as index if it isn't
    df.set_index('TIMESTEPS', inplace=True)

    # List of column names  to plot
    columns_to_plot = ['NDCG', 'AVERAGE_POPULARITY', 'COVERAGE_ITEM',]  

    df[columns_to_plot].plot()

    plt.xlabel('Timesteps')
    plt.ylabel('Value')
    title = 'Timesteps study ' + traditional_rec + '+ DIFF'
    plt.title(title)

    #  legend
    plt.legend(columns_to_plot)

    # Save the figure in PDF 
    plt.savefig(title +".pdf")
